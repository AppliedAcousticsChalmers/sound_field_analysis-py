# %% [markdown]
# # Example 7
# ## Impulse response reconstruction
# ### Generate a full audio spectrum plane from sampled unity plane wave

# %%
import numpy as np
import sys
sys.path.insert(0, '../')
from sound_field_analysis import gen, process, plot

from plotly.offline import download_plotlyjs, init_notebook_mode
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
pi = np.pi
Nsft = 5     # Spatial fourier transform order
Nrf = Nsft   # Radial filter order
Npdc = Nsft  # Decomposition order
OmegaL = np.array([[0, pi / 2],  # Looking directions for plane wave decomposition
                   [pi / 2, pi / 2]])
limit = 150  # Amplification limit of radial filters
r = 0.2      # Array radius
ac = 2       # Rigid Sphere Array
FS = 24000   # Sampling Frequency
NFFT = 1024  # FFT-Bins
AZ = 0       # Azimuth angle
EL = pi / 2  # Elevation angle

# %% [markdown]
# ## Generate Lebedev grid of order 110

# %%
quadrature_grid, _ = gen.lebedev(110)
# Out:
# Lebedev Grid

# %% [markdown]
# ## Retrieve FFT of sampled plane wave

# %%
fftData, kr = gen.sampledWave(r=r, gridData=quadrature_grid, ac=ac, FS=FS, NFFT=NFFT, AZ=AZ, EL=EL)
# Out:
# Segmented generator orders: 70 to 88
# sampledWave - Sampled Wave Generator: [##################################################] 100.0%
#
# iSpatFT - Inverse spatial Transform: [##################################################] 100.0%

# %% [markdown]
# ## Spatial Fourier Transform

# %%
Pnm = process.spatFT(Nsft, fftData, quadrature_grid)

# %% [markdown]
# ## Generate modal radial filters (MF)

# %%
dn, _ = gen.radFilter(Nrf, kr, ac, amp_maxdB=limit)

# %% [markdown]
# ## Plane wave decomposition (PDC) for supplied look directions

# %%
Y = process.PWDecomp(Npdc, OmegaL, Pnm, dn)
# Out:
# PWDecomp - Plane Wave Decomposition

# %% [markdown]
# ## Reconstruct time domain signal (TDT)

# %%
impulseResponses = process.iFFT(Y)
# Out:
# iFFT - inverse Fourier Transform

# %% [markdown]
# ### Make IR causal (flip first & second half)

# %%
impulseResponses = np.hstack(np.array_split(impulseResponses, 2, axis=1)[::-1])
# impulseResponses /= 19

# %% [markdown]
# ## Calculate frequency response

# %%
spectrum = 20 * np.log10(np.abs(np.fft.rfft(impulseResponses)))

# %% [markdown]
# ## Plot time signal and frequency response

# %%
plot.plot2D(impulseResponses, type='time', fs=FS)
# Out:
# <div id="488a2f18-b06d-4b5a-bbb1-a9f6ad2323b8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("488a2f18-b06d-4b5a-bbb1-a9f6ad2323b8", [{"y": [0.00020864469093329063, 0.00021083138766395115, 0.0002069101010457458, 0.0002124733747170173, 0.00020511355210213467, 0.00021405382877226486, 0.00020325492800651358, 0.0002155728946912662, 0.0002013341207775174, 0.00021703072565364828, 0.00019935103050561231, 0.00021842748319644834, 0.00019730556531263876, 0.00021976333724319647, 0.00019519764131514447, 0.0002210384661439843, 0.0001930271825743568, 0.0002222530567132855, 0.00019079412105622862, 0.0002234073042592967, 0.00018849839658967868, 0.00022450141262145284, 0.00018613995681558, 0.00022553559420645033, 0.00018371875714451313, 0.00022651007001591242, 0.00018123476071245717, 0.0002274250696842747, 0.00017868793832533135, 0.00022828083151281062, 0.0001760782684165226, 0.0002290776024964328, 0.0001734057369958507, 0.00022981563836085676, 0.00017067033759630632, 0.00023049520359368856, 0.0001678720712238557, 0.00023111657147413452, 0.