# %% [markdown]
# # Example 7
# ## Impulse response reconstruction
# ### Generate a full audio spectrum plane from sampled unity plane wave

# %%
import numpy as np
import sys
sys.path.insert(0, '../')
from sound_field_analysis import gen, process, plot

from plotly.offline import download_plotlyjs, init_notebook_mode
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
pi = np.pi
Nsft = 5     # Spatial fourier transform order
Nrf = Nsft   # Radial filter order
Npdc = Nsft  # Decomposition order
OmegaL = np.array([[0, pi / 2],  # Looking directions for plane wave decomposition
                   [pi / 2, pi / 2]])
limit = 150  # Amplification limit of radial filters
r = 0.2      # Array radius
ac = 2       # Rigid Sphere Array
FS = 24000   # Sampling Frequency
NFFT = 1024  # FFT-Bins
AZ = 0       # Azimuth angle
EL = pi / 2  # Elevation angle

# %% [markdown]
# ## Generate Lebedev grid of order 110

# %%
quadrature_grid, _ = gen.lebedev(110)
# Out:
# SOFiA Lebedev Grid

# %% [markdown]
# ## Retrieve FFT of sampled plane wave

# %%
fftData, kr = gen.swg(r=r, gridData=quadrature_grid, ac=ac, FS=FS, NFFT=NFFT, AZ=AZ, EL=EL)
# Out:
# Segmented generator orders: 70 to 88
# S/W/G - Sampled Wave Generator: [##################################################] 100.0%
#
# I/T/C - Inverse spatial Transform: [##################################################] 100.0%

# %% [markdown]
# ## Spatial Fourier Transform

# %%
Pnm = process.stc(Nsft, fftData, quadrature_grid)

# %% [markdown]
# ## Generate modal radial filters (MF)

# %%
dn, _ = gen.mf(Nrf, kr, ac, amp_maxdB=limit)
# Out:
# SOFiA M/F - Modal radial filter generator

# %% [markdown]
# ## Plane wave decomposition (PDC) for supplied look directions

# %%
Y = process.pdc(Npdc, OmegaL, Pnm, dn)
# Out:
# SOFiA P/D/C - Plane Wave Decomposition

# %% [markdown]
# ## Reconstruct time domain signal (TDT)

# %%
impulseResponses = process.tdt(Y)
# Out:
# SOFiA T/D/T - Time Domain Transform

# %% [markdown]
# ### Make IR causal (flip first & second half)

# %%
# impulseResponses = np.hstack(np.array_split(impulseResponses, 2, axis=1)[::-1])
# impulseResponses /= 19

# %% [markdown]
# ## Calculate frequency response

# %%
spectrum = 20 * np.log10(np.abs(np.fft.rfft(impulseResponses)))

# %% [markdown]
# ## Plot time signal and frequency response

# %%
plot.plot2D(impulseResponses, type='time', fs=FS)
# Out:
# <div id="c9d95bf7-7c82-4211-b284-a28ec70003ec" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c9d95bf7-7c82-4211-b284-a28ec70003ec", [{"x": [0.0, 8.503401360544217e-07, 1.7006802721088434e-06, 2.5510204081632653e-06, 3.401360544217687e-06, 4.251700680272109e-06, 5.102040816326531e-06, 5.952380952380952e-06, 6.802721088435374e-06, 7.653061224489796e-06, 8.503401360544217e-06, 9.353741496598638e-06, 1.0204081632653061e-05, 1.1054421768707481e-05, 1.1904761904761903e-05, 1.2755102040816325e-05, 1.3605442176870747e-05, 1.4455782312925169e-05, 1.530612244897959e-05, 1.6156462585034015e-05, 1.7006802721088435e-05, 1.7857142857142855e-05, 1.8707482993197275e-05, 1.95578231292517e-05, 2.0408163265306123e-05, 2.1258503401360546e-05, 2.2108843537414963e-05, 2.2959183673469387e-05, 2.3809523809523807e-05, 2.465986394557823e-05, 2.551020408163265e-05, 2.636054421768707e-05, 2.7210884353741494e-05, 2.8061224489795918e-05, 2.8911564625850338e-05, 2.976190476190476e-05, 3.061224489795918e-05, 3.14625850340136e-05, 3.231292517006803e-05, 3.316326530612244e-05, 3.401360544217687e-05, 3.486394557823129e-05, 3.571428571428571e-05, 3.656462585034014e-05, 3.741496598639455e-05, 3.826530612244898e-05, 3.91156462585034e-05, 3.996598639455782e-05, 4.0816326530612245e-05, 4.1666666666666665e-05], "y": [1.0521614043086447, -0.15741714437728999, 0.1750718717036227, -0.010364524327825047, -0.16570915352491777, 0.13122603805596672, -0.013808608656821434, -0.011863681017248613, 0.018841848757052797, -0.03024893383742272, -0.08886714580771897, 0.2515345884093697, -0.2525367813070627, 0.0978426693411579, 0.029857122226679505, -0.043604657067515026, 0.01738514363888577, -0.05761741735671909, 0.09642921969738331, -0.052673609085501144, -0.003954130178121793, 0.003448677794586034, 0.008076324602154144, -0.015790117354025805, 0.006666569423084497, 0.017541811334400845, -0.020126989884219355, -0.0019875118757217815, 0.0028027839861536376, 0.0006607254393543512, -0.0002912957490581787, 0.0023843499139484183, -0.0016615555035426094, -0.0087335751462256, 0.006535792157287312, 0.0005428346697173325, -0.005009541700099651, -0.0006801717788821374, 0.00480209912907801, -0.004783891801935485, 0.00010062616804097445, -0.0020363341429140403, 0.0013371672376380232, -0.002137092241727194, 0.00179318650603502, -0.0027140654398602184, 0.00028946414929272816, -0.0021760863600621162, 0.0015861354844500914, -0.0026170533412141522, 0.0013108082071026424, -0.002333057024158201, 0.0009180136573117474, -0.002534914514986942, 0.0013636553041637056, -0.0022303789340544253, 0.0008914511562424053, -0.002263360483582846, 0.001022680350537959, -0.0020981973141167005, 0.0007049266864380095, -0.0019837972674097014, 0.0009158602220658624, -0.0020851880429107587, 0.000740710994668391, -0.0020079538918368815, 0.0007655615136204512, -0.0019176311519999247, 0.0007592157608989733, -0.0019102478187823812, 0.0005737373213395127, -0.0018532689563007436, 0.0006580875469085132, -0.0017655782803099999, 0.0006213135833098838, -0.0018314341412734368, 0.0004894685513252125, -0.0016863269838193152, 0.0005897299365129785, -0.0017472244718177436, 0.0004917680071638988, -0.001652611931757592, 0.0004663450109554883, -0.0016668428799756587, 0.00048233514335011506, -0.0016079862328031683, 0.00042151702512737386, -0.0015981837162854944, 0.0004177889759619412, -0.0015644900893782606, 0.0003948943882570726, -0.0015391717782521981, 0.00037394214675952, -0.0015172581678459, 0.0003567107650410739, -0.0014917961002549008, 0.000339560036700342, -0.0014689473257572185, 0.00032244521863208437, -0.001447059736227942, 0.00030675149484728204, -0.001424768812912321, 0.00029157358890942816, -0.0014040040929366162, 0.00027742094299594, -0.0013835635305019952, 0.0002636473682225384, -0.0013637347548077056, 0.0002508661738739581, -0.00134434607 ...

# %%
plot.plot2D(spectrum, type='logFFT', fs=FS)
# Out:
# <div id="145deaea-5ed3-4ff1-86f5-9995b0ca9081" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("145deaea-5ed3-4ff1-86f5-9995b0ca9081", [{"x": [0.0, 480.0, 960.0, 1440.0, 1920.0, 2400.0, 2880.0, 3360.0, 3840.0, 4320.0, 4800.0, 5280.0, 5760.0, 6240.0, 6720.0, 7200.0, 7680.0, 8160.0, 8640.0, 9120.0, 9600.0, 10080.0, 10560.0, 11040.0, 11520.0, 12000.0], "y": [-2.1447473243213504, -2.144747324321343, -0.019720012589580255, -0.000347160414977466, -1.9635824116427198e-05, -2.1198267966463524e-06, -3.446247589050209e-07, -7.434556502693989e-08, -1.973568390670673e-08, -6.143066834286336e-09, -2.1718679637175117e-09, -8.570981096247157e-10, -3.8244359429625424e-10, -2.0893311756088117e-10, -1.607071009575251e-10, -1.8228778533194722e-10, -2.597782475637416e-10, -3.9975037933926537e-10, -6.213104007577051e-10, -9.54058343414358e-10, -1.4392539223126908e-09, -2.1316892598136152e-09, -3.1027795551824497e-09, -4.443652789820617e-09, -6.26978235646438e-09, -8.72550011181009e-09, -1.19898768455387e-08, -1.6282781150000423e-08, -2.1872719402851907e-08, -2.9084541708354418e-08, -3.830888459270563e-08, -5.001238901903929e-08, -6.474909488248536e-08, -8.317306791651287e-08, -1.060523004769464e-07, -1.3428410510641113e-07, -1.6891215710081657e-07, -2.1114539726634074e-07, -2.6237939371526746e-07, -3.242203835329802e-07, -3.9851325180089805e-07, -4.873741326502038e-07, -5.932295262887146e-07, -7.188636832239223e-07, -8.674772730689025e-07, -1.0427605250417857e-06, -1.248985574054277e-06, -1.4911234097470647e-06, -1.7749923677970416e-06, -2.1074464094958654e-06, -2.4966131299386942e-06, -2.952192904820261e-06, -3.4858325521332e-06, -4.111588309424653e-06, -4.8464948048848355e-06, -5.7112575290024905e-06, -6.731087923135264e-06, -7.936699706858126e-06, -9.365485496350446e-06, -1.1062890683568419e-05, -1.3083999261100375e-05, -1.549534219065747e-05, -1.8376932835175693e-05, -2.1824526489967833e-05, -2.5952090777409405e-05, -3.0894461491841804e-05, -3.6810143572323106e-05, -4.3884199440237303e-05, -5.233114693863396e-05, -6.239776684840972e-05, -7.43656956478789e-05, -8.855365285540417e-05, -0.00010531912537316762, -0.00012505930388032407, -0.00014821103951190772, -0.00017524956437776746, -0.0002066856979904474, -0.00024306124432538442, -0.00028494227451970406, -0.00033290998685391645, -0.00038754884420082414, -0.0004494317074347263, -0.0005191017162305845, -0.0005970507164491396, -0.0006836940963177446, -0.0007793419749678595, -0.0008841667847388413, -0.000998167404376102, -0.0011211301320674953, -0.0012525869344892364, -0.0013917715669177356, -0.0015375743282593373, -0.001688496387547017, -0.0018426047918157018, -0.001997489431627881, -0.002150223395011494, -0.0022973282752717255, -0.00243474610675899, -0.0025578196789652436, -0.002661283016866089, -0.0027392638118687467, -0.002785299538782728, -0.002792368903616943, -0.002752940136316875, -0.002659037483365948, -0.002502327078057135, -0.002274223192428917, -0.001966015725883462, -0.0015690196927042332, -0.0010747474640428341, -0.00047510463903622905, 0.00023738930266840115, 0.0010693539421727015, 0.0020262721397511984, 0.0031121822891756724, 0.004329334218546832, 0.005677803017710999, 0.007155053645444041, 0.008755447793123096, 0.010469683384308447, 0.012284156601920799, 0.014180236917498298, 0.01613344786622497, 0.018112551061742116, 0.020078539165746263, 0.02198355639782341, 0.02376978401381847, 0.02536835437047448, 0.026698391948535568, 0.027666323774632524, 0.02816565483646701, 0.02807746441687325, 0.027271942282112716, 0.02561134120031235, 0.022954761524145377, 0.01916518644287348, 0.014119129908840646, 0.0077191171405315215, -9.103442573361963e-05, -0.009308542977945462, -0.019852505722685515, -0.031544746161755566, -0.044092741709814774, -0.05707718252584388, -0.06994692242643191, -0.0820238775810077, -0.09 ...
